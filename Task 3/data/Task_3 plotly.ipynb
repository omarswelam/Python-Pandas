# %% [markdown]
# # Importing data

# %%
import pandas as pd
from plotly.offline import init_notebook_mode, iplot
import plotly.graph_objects as go
import plotly.express as px
import numpy as np
init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
reviews = pd.read_csv('winemag-data-130k-v2.csv.zip', index_col=0)
reviews.head(5)
# Out:
#     country                                        description  \
# 0     Italy  Aromas include tropical fruit, broom, brimston...
# 1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2        US  Tart and snappy, the flavors of lime flesh and...
# 3        US  Pineapple rind, lemon pith and orange blossom ...
# 4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2         taster_name  \
# 0                 Etna                NaN       Kerin O’Keefe
# 1                  NaN                NaN          Roger Voss
# 2    Willamette Valley  Willamette Valley        Paul Gregutt
# 3  Lake Michigan Shore                NaN  Alexander Peartree
# 4    Willamette Valley  Willamette Valley        Paul Gregutt
#
#   taster_twitter_handle                                              title  \
# 0          @kerinokeefe                  Nicosia 2013 Vulkà Bianco  (Etna)
# 1            @vossroger      Quinta dos Avidagos 2011 Avidagos Red (Douro)
# 2           @paulgwine       Rainstorm 2013 Pinot Gris (Willamette Valley)
# 3                   NaN  St. Julian 2013 Reserve Late Harvest Riesling ...
# 4           @paulgwine   Sweet Cheeks 2012 Vintner's Reserve Wild Child...
#
#           variety               winery
# 0     White Blend              Nicosia
# 1  Portuguese Red  Quinta dos Avidagos
# 2      Pinot Gris            Rainstorm
# 3        Riesling           St. Julian
# 4      Pinot Noir         Sweet Cheeks

# %% [markdown]
# # Country based analysis

# %%
countries = reviews.groupby('country').agg({'points':'mean','price':'mean','variety':'count'})
countries.head(3)
# Out:
#               points      price  variety
# country
# Argentina  86.710263  24.510117     3800
# Armenia    87.500000  14.500000        2
# Australia  88.580507  35.437663     2329

# %%
px.choropleth(countries, locations=countries.index,locationmode='country names', color='points')
# Out:
# <div>                            <div id="abe1a903-6a68-403a-a44e-a715b4498939" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("abe1a903-6a68-403a-a44e-a715b4498939")) {                    Plotly.newPlot(                        "abe1a903-6a68-403a-a44e-a715b4498939",                        [{"coloraxis": "coloraxis", "geo": "geo", "hovertemplate": "country=%{location}<br>points=%{z}<extra></extra>", "locationmode": "country names", "locations": ["Argentina", "Armenia", "Australia", "Austria", "Bosnia and Herzegovina", "Brazil", "Bulgaria", "Canada", "Chile", "China", "Croatia", "Cyprus", "Czech Republic", "Egypt", "England", "France", "Georgia", "Germany", "Greece", "Hungary", "India", "Israel", "Italy", "Lebanon", "Luxembourg", "Macedonia", "Mexico", "Moldova", "Morocco", "New Zealand", "Peru", "Portugal", "Romania", "Serbia", "Slovakia", "Slovenia", "South Africa", "Spain", "Switzerland", "Turkey", "US", "Ukraine", "Uruguay"], "name": "", "type": "choropleth", "z": [86.71026315789474, 87.5, 88.58050665521684, 90.10134529147982, 86.5, 84.67307692307692, 87.93617021276596, 89.36964980544747, 86.4935152057245, 89.0, 87.21917808219177, 87.18181818181819, 87.25, 84.0, 91.58108108108108, 88.84510931064138, 87.68604651162791, 89.85173210161663, 87.28326180257511, 89.1917808219178, 90.22222222222223, 88.47128712871287, 88.56223132036847, 87.68571428571428, 88.66666666666667, 86.83333333333333, 85.25714285714285, 87.20338983050847, 88.57142857142857, 88.3030303030303, 83.5625, 88.25021964505359, 86.4, 87.5, 87.0, 88.06896551724138, 88.05638829407566, 87.28833709556058, 88.57142857142857, 88.08888888888889, 88.56372009393806, 84.07142857142857, 86.75229357798165]}],                        {"coloraxis": {"colorbar": {"title": {"text": "points"}}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]]}, "geo": {"center": {}, "domain": {"x": [0.0, 1.0], "y": [0.0, 1.0]}}, "legend": {"tracegroupgap": 0}, "margin": {"t": 60}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [ ...

# %% [markdown]
# # Analysing points and prices distribution

# %%
reviews[['price','points']].fillna(value=reviews[['price','points']].mean()).values
# Out:
# array([[35.36338913, 87.        ],
#        [15.        , 87.        ],
#        [14.        , 87.        ],
#        ...,
#        [30.        , 90.        ],
#        [32.        , 90.        ],
#        [21.        , 90.        ]])

# %%
x = reviews[['price','points']].fillna(value=reviews[['price','points']].mean()).values

# %%
x.shape
# Out:
# (129971, 2)

# %%
cov = np.cov(x,rowvar=False)
cov
# Out:
# array([[1566.34415673,   48.37851588],
#        [  48.37851588,    9.23995971]])

# %%
mean = np.mean(x, axis=0,keepdims=True)
mean
# Out:
# array([[35.36338913, 88.44713821]])

# %%
def multivariate_gaussian_nonnormalized(x, d=2, mean=mean, covariance=cov):
    """pdf of the multivariate normal distribution."""
    x_m = x - mean
    return np.exp(np.diag(-(np.dot(np.dot(x_m,np.linalg.inv(cov)),x_m.T))))

# %%
X = np.arange(mean[0,0]-2*cov[0,0]**0.5,mean[0,0]+2*cov[0,0]**0.5, cov[0,0]**0.5/20)
Y = np.arange(mean[0,1]-2*cov[1,1]**0.5, mean[0,1]+2*cov[1,1]**0.5, cov[1,1]**0.5/20)
Xgrid, Ygrid = np.meshgrid(X,Y)
mapped = list(map(list,zip(Xgrid.ravel(),Ygrid.ravel())))
Z = multivariate_gaussian_nonnormalized(mapped).reshape(Ygrid.shape)

# %%
Y.shape
# Out:
# (81,)

# %%
X.shape
# Out:
# (80,)

# %%
Z.shape
# Out:
# (81, 80)

# %%
fig = go.Figure(data=[go.Surface(z=Z,x=X,y=Y)])

# %%
fig.show()
# Out:
# <div>                            <div id="0a87eb0f-0cbb-49c1-b8ab-7b3c91f48f78" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0a87eb0f-0cbb-49c1-b8ab-7b3c91f48f78")) {                    Plotly.newPlot(                        "0a87eb0f-0cbb-49c1-b8ab-7b3c91f48f78",                        [{"type": "surface", "x": [-43.79074296005733, -41.811889657806255, -39.83303635555518, -37.854183053304105, -35.87532975105303, -33.896476448801955, -31.91762314655088, -29.938769844299806, -27.95991654204873, -25.981063239797656, -24.00220993754658, -22.023356635295507, -20.04450333304443, -18.065650030793357, -16.086796728542282, -14.107943426291207, -12.129090124040133, -10.150236821789058, -8.171383519537983, -6.192530217286908, -4.213676915035833, -2.2348236127847585, -0.2559703105336837, 1.7228829917173911, 3.701736293968466, 5.680589596219541, 7.6594428984706155, 9.63829620072169, 11.617149502972765, 13.59600280522384, 15.574856107474915, 17.55370940972599, 19.532562711977064, 21.511416014228146, 23.490269316479214, 25.46912261873028, 27.447975920981364, 29.426829223232446, 31.405682525483513, 33.38453582773458, 35.36338912998566, 37.342242432236745, 39.32109573448781, 41.29994903673888, 43.27880233898996, 45.257655641241044, 47.23650894349211, 49.21536224574318, 51.19421554799426, 53.17306885024534, 55.15192215249641, 57.13077545474748, 59.10962875699856, 61.08848205924964, 63.06733536150071, 65.04618866375178, 67.02504196600286, 69.00389526825394, 70.98274857050501, 72.96160187275608, 74.94045517500716, 76.91930847725824, 78.89816177950931, 80.87701508176038, 82.85586838401146, 84.83472168626254, 86.81357498851362, 88.79242829076468, 90.77128159301576, 92.75013489526684, 94.7289881975179, 96.70784149976897, 98.68669480202006, 100.66554810427114, 102.64440140652222, 104.62325470877327, 106.60210801102436, 108.58096131327544, 110.55981461552649, 112.53866791777757], "y": [82.36767780192203, 82.51966431206783, 82.67165082221364, 82.82363733235944, 82.97562384250524, 83.12761035265105, 83.27959686279685, 83.43158337294265, 83.58356988308846, 83.73555639323426, 83.88754290338007, 84.03952941352587, 84.19151592367167, 84.34350243381748, 84.49548894396328, 84.64747545410908, 84.79946196425489, 84.95144847440069, 85.1034349845465, 85.2554214946923, 85.4074080048381, 85.55939451498391, 85.71138102512971, 85.86336753527551, 86.01535404542132, 86.16734055556712, 86.31932706571293, 86.47131357585873, 86.62330008600453, 86.77528659615034, 86.92727310629614, 87.07925961644195, 87.23124612658775, 87.38323263673355, 87.53521914687936, 87.68720565702516, 87.83919216717096, 87.99117867731677, 88.14316518746257, 88.29515169760838, 88.44713820775418, 88.59912471789998, 88.75111122804579, 88.90309773819159, 89.0550842483374, 89.2070707584832, 89.359057268629, 89.5110437787748, 89.66303028892061, 89.81501679906641, 89.96700330921222, 90.11898981935802, 90.27097632950382, 90.42296283964963, 90.57494934979543, 90.72693585994124, 90.87892237008704, 91.03090888023284, 91.18289539037865, 91.33488190052445, 91.48686841067025, 91.63885492081606, 91.79084143096186, 91.94282794110767, 92.09481445125347, 92.24680096139927, 92.39878747154508, 92.55077398169088, 92.70276049183668, 92.85474700198249, 93.00673351212829, 93.1587200222741, 93.3107065324199, 93.4626930425657, 93.61467955271151, 93.76666606285731, 93.91865257300311, 94.07063908314892, 94.22262559329472, 94.37461210344053, 94.52659861358633], "z": [[0.003327356823792667, 0.0038260593842089157, 0.004373344245714168, 0.004969185960212795, 0.005612630642945983, 0.006301693910185271, 0.007033277840804897, 0.007803112556610457, 0.008605727636248915, 0.00943445788947307, 0.010281487024594079, 0.011137931463565788, 0.011993965037764176, 0.012838983593920472, 0.01366180673169138 ...

# %% [markdown]
# # Plotting average price vs average points of different wine

# %%
reviews[['winery','variety','points','price']].isna().sum()
# Out:
# winery        0
# variety       1
# points        0
# price      8996
# dtype: int64

# %%
avg_points_price = reviews[['winery','variety','points','price']].dropna().groupby('variety')\
                        .mean('points').sort_values(by='points', ascending=False)

# %%
avg_points_price
# Out:
#                         points  price
# variety
# Terrantez            95.000000  236.0
# Tinta del Pais       95.000000   47.5
# Gelber Traminer      95.000000   35.0
# Bual                 94.333333  100.0
# Riesling-Chardonnay  94.000000   40.0
# ...                        ...    ...
# Shiraz-Tempranillo   82.000000    8.5
# Picapoll             82.000000   21.0
# Aidani               82.000000   27.0
# Airen                81.666667    9.0
# Chancellor           80.500000   16.0
#
# [697 rows x 2 columns]

# %%
scatter = go.Scatter(x=avg_points_price['points'],y=avg_points_price['price'], mode='markers')
layout = go.Layout(title = "price vs points", yaxis_title='price', xaxis_title='points', title_x=0.5)

# %%
iplot({"data": scatter,"layout": layout})
# Out:
# <div>                            <div id="d929d294-68a7-451a-bd93-123c234f9e6d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d929d294-68a7-451a-bd93-123c234f9e6d")) {                    Plotly.newPlot(                        "d929d294-68a7-451a-bd93-123c234f9e6d",                        [{"mode": "markers", "type": "scatter", "x": [95.0, 95.0, 95.0, 94.33333333333333, 94.0, 94.0, 93.0, 93.0, 93.0, 93.0, 92.5, 92.5, 92.0, 92.0, 92.0, 92.0, 92.0, 92.0, 92.0, 92.0, 92.0, 92.0, 92.0, 92.0, 92.0, 91.66666666666667, 91.5, 91.5, 91.33333333333333, 91.0, 91.0, 91.0, 91.0, 91.0, 91.0, 91.0, 91.0, 91.0, 91.0, 91.0, 91.0,

#  'Chardonnay',
#  'Cabernet Sauvignon',
#  'Red Blend',
#  'Bordeaux-style Red Blend',
#  'Riesling',
#  'Sauvignon Blanc',
#  'Syrah',
#  'Rosé',
#  'Merlot']

# %%
heatmapper = reviews.query('winery in @common_winery10 and \
                           variety in @common_wine10').groupby(['winery','variety'])['points'].count().reset_index()

# %%
heatmap = go.Heatmap(z=heatmapper['points'],
                    x=heatmapper['winery'],
                   y=heatmapper['variety'],
                    connectgaps=True )

# %%
iplot({"data": heatmap})
# Out:
# <div>                            <div id="e4f6142a-dd41-44e8-a4f5-3935aee89eb7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e4f6142a-dd41-44e8-a4f5-3935aee89eb7")) {                    Plotly.newPlot(                        "e4f6142a-dd41-44e8-a4f5-3935aee89eb7",                        [{"connectgaps": true, "type": "heatmap", "x": ["Chateau Ste. Michelle", "Chateau Ste. Michelle", "Chateau Ste. Michelle", "Chateau Ste. Michelle", "Chateau Ste. Michelle", "Chateau Ste. Michelle", "Chateau Ste. Michelle", "Chateau Ste. Michelle", "Columbia Crest", "Columbia Crest", "Columbia Crest", "Columbia Crest", "Columbia Crest", "Columbia Crest", "Columbia Crest", "Columbia Crest", "Concha y Toro", "Concha y Toro", "Concha y Toro", "Concha y Toro", "Concha y Toro", "Concha y Toro", "Concha y Toro", "DFJ Vinhos", "DFJ Vinhos", "DFJ Vinhos", "DFJ Vinhos", "DFJ Vinhos", "Georges Duboeuf", "Georges Duboeuf", "Kendall-Jackson", "Kendall-Jackson", "Kendall-Jackson", "Kendall-Jackson", "Kendall-Jackson", "Kendall-Jackson", "Kendall-Jackson", "Kendall-Jackson", "Kendall-Jackson", "Kendall-Jackson", "Louis Latour", "Louis Latour", "Testarossa", "Testarossa", "Testarossa", "Testarossa", "Testarossa", "Williams Selyem", "Williams Selyem", "Wines & Winemakers", "Wines & Winemakers", "Wines & Winemakers"], "y": ["Bordeaux-style Red Blend", "Cabernet Sauvignon", "Chardonnay", "Merlot", "Red Blend", "Riesling", "Sauvignon Blanc", "Syrah", "Bordeaux-style Red Blend", "Cabernet Sauvignon", "Chardonnay", "Merlot", "Red Blend", "Riesling", "Sauvignon Blanc", "Syrah", "Cabernet Sauvignon", "Chardonnay", "Merlot", "Pinot Noir", "Riesling", "Sauvignon Blanc", "Syrah", "Cabernet Sauvignon", "Chardonnay", "Pinot Noir", "Red Blend", "Ros\u00e9", "Chardonnay", "Ros\u00e9", "Bordeaux-style Red Blend", "Cabernet Sauvignon", "Chardonnay", "Merlot", "Pinot Noir", "Red Blend", "Riesling", "Ros\u00e9", "Sauvignon Blanc", "Syrah", "Chardonnay", "Pinot Noir", "Chardonnay", "Pinot Noir", "Red Blend", "Sauvignon Blanc", "Syrah", "Chardonnay", "Pinot Noir", "Merlot", "Ros\u00e9", "Sauvignon Blanc"], "z": [3, 31, 43, 37, 4, 27, 17, 12, 6, 26, 33, 18, 14, 8, 11, 10, 33, 27, 14, 11, 2, 23, 14, 1, 6, 3, 2, 21, 30, 1, 4, 22, 31, 12, 18, 8, 6, 1, 7, 6, 107, 91, 85, 122, 1, 1, 8, 41, 140, 2, 24, 4]}],                        {"template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.777777777 ...
